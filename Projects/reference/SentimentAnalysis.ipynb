# %% [markdown]
# # Twitter Sentiment Analysis
#
# Extract tweets about a particular topic from twitter (recency = 1-7 days) and analyze the opinion of tweeples (people who use twitter.com) on this topic as positive, negative or neutral.
#
# ## What is sentiment analysis?
#
# Process of ‘computationally’ determining whether a piece of writing is positive, negative or neutral. It’s also known as opinion mining, deriving the opinion or attitude of a speaker.
#
# ## Why sentiment analysis?
#
# ### Business:
#
# In marketing field companies use it to develop their strategies, to understand customers’ feelings towards products or brand, how people respond to their campaigns or product launches and why consumers don’t buy some
# products.
# ### Politics:
# In political field, it is used to keep track of political view, to detect consistency and inconsistency between statements and actions at the government level. It can be used to predict election results as well!
# ### Public Actions:
# Sentiment analysis also is used to monitor and analyse social phenomena, for the spotting of potentially dangerous situations and determining the general mood of the blogosphere.
#
# ## Steps involved in Sentiment Analysis
#
# ### Traininig
#
# <img src="training.png">
#
# ### Prediction
#
# <img src="pred.png">
#
# ---
#
# ## Training the Classifiers
#
# The classifiers need to be trained and to do that, we need to list manually classified tweets. Let's start with 3 positive, 3 neutral and 3 negative tweets.
#
# ### Preprocess tweets
# 1. Lower Case - Convert the tweets to lower case.
# 2. URLs - eliminate all of these URLs via regular expression matching or replace with generic word URL.
# 3. @username - we can eliminate "@username" via regex matching or replace it with generic word AT_USER.
# 4. #hashtag - hash tags can give us some useful information, so it is useful to replace them with the exact same word without the hash. E.g. #nike replaced with 'nike'.
# 5. Punctuations and additional white spaces - remove punctuation at the start and ending of the tweets. E.g: ' the day is beautiful! ' replaced with 'the day is beautiful'. It is also helpful to replace multiple whitespaces with a single whitespace

# %%
import os
os.getcwd()
# Out:
# 'E:\\DSP_January2019_BLR\\PythonTextMiningClass\\Twitter Sentiment Analysis'

# %%
#import regex
import re

#start process_tweet
def processTweet(tweet):
    # process the tweets

    #Convert to lower case
    tweet = tweet.lower()
    #Convert www.* or https?://* to URL
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL',tweet)
    #Convert @username to AT_USER
    tweet = re.sub('@[^\s]+','',tweet)
    #Remove additional white spaces
    tweet = re.sub('[\s]+', ' ', tweet)
    #Replace #word with word
    #  #NIKE ---> NIKE
    #tweet = re.sub(r'#([^\s]+)', r'HASH\1', tweet)
    tweet = re.sub(r'[\.!:\?\-\'\"\\/]', r'', tweet)
    #trim
    
    tweet = tweet.strip('\'"')
    return tweet
#end


"\d" - 0-9
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-ac6c0fde60b6> in <module>()
#      25
#      26
# ---> 27 "\d" - 0-9
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
#Read the tweets one by one and process it
fp = open('Files/SampleTweets.txt', 'r') # r -> read w -> write rw ->
line = fp.readline() # identify a line based on \n

while line:
    processedTweet = processTweet(line)
    print(processedTweet)
    line = fp.readline() # reads till EOF
#end loop
fp.close()
# Out:
#  hey cici sweetheart just wanted to let u know i luv u oh and will the mixtape drop soon fantasy ride may 5th
#
#  i heard about that contest congrats girl URL
#
# unc #ncaa champs franklin st i was there wild and crazy nothing like itever URL
#
# do you share more #jokes #quotes #music #photos or #news #articles on #facebook or #twitter
#
# good night #twitter and #thelegionofthefallen 545am cimes awfully early
#
# i just finished a 266 mi run with a pace of 1114mi with nike+ gps #nikeplus #makeitcount
#
# disappointing day attended a car boot sale to raise some funds for the sanctuary, made a total of 88p after the entry fee  sigh
#
#
#
# no more taking irish car bombs with strange australian women who can drink like rockstarsmy head hurts
#
# just had some bloodwork done my arm arm arm arm hurts

# %% [markdown]
# ### Feature Vector
#
# A good feature vector directly determines how successful your classifier will be.
#
# The feature vector is used to build a model which the classifier learns from the training data and further can be used to classify previously unseen data.
#
# We can use the presence/absence of words that appear in tweet as features.
#
# In the training data, consisting of positive, negative and neutral tweets, we can split each tweet into words and add each word to the feature vector.
#
# Some of the words might not have any say in indicating the sentiment of a tweet and hence we can filter them out.
#
# Adding individual (single) words to the feature vector is referred to as 'unigrams' approach.
#
# Some of the other feature vectors also add 'bi-grams' in combination with 'unigrams'. For example, 'not good' (bigram) completely changes the sentiment compared to adding 'not' and 'good' individually.
#
# Here, for simplicity, we will only consider the unigrams. Before adding the words to the feature vector, we need to preprocess them in order to filter, otherwise, the feature vector will explode.
#
# #### Filtering tweet words (for feature vector)
#
# 1. Stop words - a, is, the, with etc. The full list of stop words can be found at Stop Word List. These words don't indicate any sentiment and can be removed.
# 2. Repeating letters - if you look at the tweets, sometimes people repeat letters to stress the emotion. E.g. hunggrryyy, huuuuuuungry for 'hungry'. We can look for 2 or more repetitive letters in words and replace them by 2 of the same.
# 3. Punctuation - we can remove punctuation such as comma, single/double quote, question marks at the start and end of each word. E.g. beautiful!!!!!! replaced with beautiful

# %%
#initialize stopWords
stopWords = []

#start replaceTwoOrMore
def replaceTwoOrMore(s):
    #look for 2 or more repetitions of character and replace with the character itself
    pattern = re.compile(r"(.)\1{2,}", re.DOTALL)
    return pattern.sub(r"\1\1", s)
#end

#start getStopWordList
def getStopWordList(stopWordListFileName):
    #read the stopwords file and build a list
    stopWords = []
    stopWords.append('AT_USER')
    stopWords.append('URL')

    fp = open(stopWordListFileName, 'r')
    line = fp.readline()
    while line:
        word = line.strip()
        stopWords.append(word)
        line = fp.readline()
    fp.close()
    return stopWords
#end

#start getfeatureVector
def getFeatureVector(tweet,stopWords):
    featureVector = []
    #split tweet into words
    words = tweet.split()
    for w in words:
        #replace two or more with two occurrences
        w = replaceTwoOrMore(w)
        #strip punctuation
        w = w.strip('\'"?,.')
        #check if the word stats with an alphabet
        val = re.search(r"^[a-zA-Z][a-zA-Z0-9]*$", w)
        #ignore if it is a stop word
        if(w in stopWords or val is None):
            continue
        else:
            featureVector.append(w.lower())
    return list(set(featureVector))
#end

#Read the tweets one by one and process it
fp = open('Files/SampleTweets.txt', 'r')
line = fp.readline()

st = open('Files/StopWords.txt', 'r')
stopWords = getStopWordList('Files/StopWords.txt')

while line:
    processedTweet = processTweet(line)
    featureVector = getFeatureVector(processedTweet,stopWords)
    print(featureVector)
    line = fp.readline()
#end loop
fp.close()
# Out:
# ['luv', 'drop', 'sweetheart', 'mixtape', 'hey', 'fantasy', 'cici', 'ride', 'soon', 'oh']
# []
# ['heard', 'congrats', 'contest', 'girl']
# []
# ['unc', 'crazy', 'itever', 'st', 'franklin', 'wild', 'champs']
# []
# ['share']
# []
# ['awfully', 'night', 'cimes']
# []
# ['pace', 'run', 'finished', 'gps', 'mi']
# []
# ['entry', 'sale', 'day', 'raise', 'sanctuary', 'total', 'boot', 'disappointing', 'attended', 'car', 'fee', 'sigh', 'funds']
# []
# []
# []
# ['australian', 'bombs', 'drink', 'rockstarsmy', 'hurts', 'car', 'taking', 'women', 'head', 'strange', 'irish']
# []
# ['arm', 'hurts', 'bloodwork']

# %%
# For a bigger training dataset
import csv
#Read the tweets one by one and process it
inpTweets = csv.reader(open('Files/SampleTrainingData.csv', 'r'), delimiter=',')
tweets = []
for row in inpTweets:
    sentiment = row[0]
    tweet = row[1]
    processedTweet = processTweet(tweet)
    featureVector = getFeatureVector(processedTweet,stopWords)
    tweets.append((featureVector, sentiment));
#end loop

# %%
tweets[15000:15010]
# Out:
# [(['job',
#    'chris',
#    'grader',
#    'totally',
#    'whens',
#    'coming',
#    'funny',
#    'smarter',
#    'fun',
#    'awesome'],
#   'positive'),
#  (['moshpits'], 'positive'),
#  ([], 'positive'),
#  (['carolina', 'south'], 'positive'),
#  (['im', 'goodnight', 'xx', 'bed'], 'positive'),
#  (['dont', 'fridge', 'inside', 'love', 'garage', 'house'], 'positive'),
#  (['sorry', 'lol', 'talking', 'idea'], 'positive'),
#  (['factory',
#    'nutritional',
#    'menuahh',
#    'nodepressing',
#    'waiter',
#    'studentsthe',
#    'cheesecake'],
#   'positive'),
#  (['tribute', 'zomg', 'band', 'boys', 'fun', 'beach'], 'positive'),
#  (['tweets', 'lol', 'monday', 'ready', 'everyones', 'checkin'], 'positive')]

# %%
#start extract_features
def extract_features(tweet):
    tweet_words = set(tweet)
    features = {}
    for word in featureList:
        features['contains(%s)' % word] = (word in tweet_words)
    return features
#end

# %% [markdown]
# #### Bulk Extraction of Features

# %%
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
#from nltk.corpus import movie_reviews
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet

# %%
#Read the tweets one by one and process it
inpTweets = csv.reader(open('Files/SampleTrainingData.csv', 'r'), delimiter=',', quotechar='|')
stopWords = getStopWordList('Files/StopWords.txt')
featureList = []

# Get tweet words
tweets = []
for row in inpTweets:
    sentiment = row[0]
    tweet = row[1]
    processedTweet = processTweet(tweet)
    featureVector = getFeatureVector(processedTweet, stopWords)
    featureList.extend(featureVector)
    tweets.append((featureVector, sentiment));
#end loop

# Remove featureList duplicates
featureList = list(set(featureList))

# Extract feature vector for all tweets in one shote
training_set = nltk.classify.util.apply_features(extract_features, tweets)

# %%
#This is a feature vector

# The first step in creating a classifier is deciding what features of the input are relevant, 
# and how to encode those features.

# The returned dictionaries for all tweets, known as a feature set, 
# maps from feature names to their values.

# does a tweet contains(a certain feature word (pos or neg)): True or False

# Feature Words or the complete BoW
# This BoW is a mix of pos and neg words
# In a neg tweet : I'll check for each and every word in the BoW

training_set[2] # neg

"pathetic service and  bad fod"
# contains("awesome") : False
# contains("ambience") : False
# contains("awareness") : False
# contains("beautiful") : False
# ..
# contains("bad") : True
# contains("fist") : False
# contains("fillet") : False
# contains("fever") : False
# contains("food") : True
# Out:
# ({'contains(ivy)': False,
#   'contains(rose)': False,
#   'contains(episode)': False,
#   'contains(span)': False,
#   'contains(sandey)': False,
#   'contains(raincoat)': False,
#   'contains(imissyou)': False,
#   'contains(knowu)': False,
#   'contains(downfall)': False,
#   'contains(schemes)': False,
#   'contains(puh)': False,
#   'contains(feelings)': False,
#   'contains(sadd)': False,
#   'contains(rollerblades)': False,
#   'contains(lolx)': False,
#   'contains(regrow)': False,
#   'contains(covering)': False,
#   'contains(raid)': False,
#   'contains(niteim)': False,
#   'contains(brownies)': False,
#   'contains(poppies)': False,
#   'contains(basically)': False,
#   'contains(winging)': False,
#   'contains(thise)': False,
#   'contains(yourfirst)': False,
#   'contains(obnoxiously)': False,
#   'contains(abby)': False,
#   'contains(roll)': False,
#   'contains(twitterbirds)': False,
#   'contains(jonno)': False,
#   'contains(faux)': False,
#   'contains(lift)': False,
#   'contains(nowhowever)': False,
#   'contains(apparantly)': False,
#   'contains(melbourne)': False,
#   'contains(twitteron)': False,
#   'contains(pwn)': False,
#   'contains(isight)': False,
#   'contains(accent)': False,
#   'contains(somethings)': False,
#   'contains(bands)': False,
#   'contains(jayneoni)': False,
#   'contains(lmsadittyaoo)': False,
#   'contains(consult)': False,
#   'contains(sat)': False,
#   'contains(onto)': False,
#   'contains(topanga)': False,
#   'contains(parenting)': False,
#   'contains(jessie)': False,
#   'contains(gloomy)': False,
#   'contains(benjamin)': False,
#   'contains(parcel)': False,
#   'contains(librarian)': False,
#   'contains(portfolio)': False,
#   'contains(americas)': False,
#   'contains(primer)': False,
#   'contains(workin)': False,
#   'contains(oddkode)': False,
#   'contains(stripper)': False,
#   'contains(sweetest)': False,
#   'contains(layin)': False,
#   'contains(dinnerdrinksdessert)': False,
#   'contains(kegger)': False,
#   'contains(unicorn)': False,
#   'contains(wordpress)': False,
#   'contains(french)': False,
#   'contains(some1)': False,
#   'contains(tweeten)': False,
#   'contains(avant)': False,
#   'contains(qot)': False,
#   'contains(recessioon)': False,
#   'contains(staring)': False,
#   'contains(girlie)': False,
#   'contains(academy)': False,
#   'contains(graduates)': False,
#   'contains(nip)': False,
#   'contains(nkfafollow)': False,
#   'contains(seenalmost)': False,
#   'contains(breast)': False,
#   'contains(gp)': False,
#   'contains(thrift)': False,
#   'contains(bacon)': False,
#   'contains(tend)': False,
#   'contains(felix)': False,
#   'contains(pride)': False,
#   'contains(rights)': False,
#   'contains(pakistan)': False,
#   'contains(sulking)': False,
#   'contains(hospitle)': False,
#   'contains(skull)': False,
#   'contains(angeles)': False,
#   'contains(caramels)': False,
#   'contains(sun)': False,
#   'contains(irritation)': False,
#   'contains(mythos)': False,
#   'contains(cutee)': False,
#   'contains(tonights)': False,
#   'contains(farsi)': False,
#   'contains(pan)': False,
#   'contains(umbrella)': False,
#   'contains(amuses)': False,
#   'contains(nicee)': False,
#   'contains(knowmontoya)': False,
#   'contains(c0uld)': False,
#   'contains(dentistask)': False,
#   'contains(dani)': False,
#   'contains(fuss)': False,
#   'contains(amity)': False,
#   'contains(sequence)': False,
#   'contains(cctso)': False,
#   'contains(chewed)': False,
#   'contains(txtnmy)': False,
#   'contains(whens)': False,
#   'contains(lollipops)': False,
#   'contains(feelingodd)': False,
#   'contains(nd)': False,
#   'contains(thanksstill)': False,
#   'contains(iron)': False,
#   'contains(functionluckily)': False,
#   'contains(squished)': False,
#   'contains(shannon)': False,
#   'contains(popcorn)': False,
#   'contains(geekby)': False,
#   'contains(hairstyle)': False,
#   'contains(philippines)': False,
#   'contains(pages)': False,
#   'contains(tomorrow)': False,
#   'contains(wheels)': False,
#   'contains(toend)': False,
#   'contains(plumbers)': False,
#   'contains(contemplating)': False,
#   'contains(truthwe)': False,
#   'contains(delusions)': False,
#   'contains(ttyl)': False,
#   'contains(wordcamp)': False,
#   'contains(parking)': False,
#   'contains(hrm)': False,
#   'contains(hardly)': False,
#   'contains(scurred)': False,
#   'contains(prospect)': False,
#   'contains(herehow)': False,
#   'contains(arguably)': False,
#   'contains(eatin)': False,
#   'contains(lemonaid)': False,
#   'contains(reregister)': False,
#   'contains(grandmas)': False,
#   'contains(familyyeah)': False,
#   'contains(corner)': False,
#   'contains(costco)': False,
#   'contains(disse)': False,
#   'contains(touched)': False,
#   'contains(stinking)': False,
#   'contains(throwin)': False,
#   'contains(autism)': False,
#   'contains(jazzy)': False,
#   'contains(france)': False,
#   'contains(console)': False,
#   'contains(ohthen)': False,
#   'contains(induction)': False,
#   'contains(camp)': False,
#   'contains(homeade)': False,
#   'contains(ericas)': False,
#   'contains(expired)': False,
#   'contains(appearances)': False,
#   'contains(suggest)': False,
#   'contains(paigey)': False,
#   'contains(permanent)': False,
#   'contains(priuses)': False,
#   'contains(bnp)': False,
#   'contains(favourites)': False,
#   'contains(disconnected)': False,
#   'contains(huhuh)': False,
#   'contains(nasty)': False,
#   'contains(fomos)': False,
#   'contains(manson)': False,
#   'contains(flately)': False,
#   'contains(beautiful)': False,
#   'contains(denise)': False,
#   'contains(unter)': False,
#   'contains(eyebags)': False,
#   'contains(bother)': False,
#   'contains(oversast)': False,
#   'contains(sons)': False,
#   'contains(croissants)': False,
#   'contains(starbulletin)': False,
#   'contains(jashley)': False,
#   'contains(fanboys)': False,
#   'contains(bradford)': False,
#   'contains(class)': False,
#   'contains(jealous)': False,
#   'contains(twitpic)': False,
#   'contains(shiteous)': False,
#   'contains(loveqonna)': False,
#   'contains(horse)': False,
#   'contains(liftoff)': False,
#   'contains(barnyard)': False,
#   'contains(outtsidee)': False,
#   'contains(disaster)': False,
#   'contains(strting)': False,
#   'contains(rubs)': False,
#   'contains(tussauds)': False,
#   'contains(chemist)': False,
#   'contains(rihanna)': False,
#   'contains(links)': False,
#   'contains(obligatory)': False,
#   'contains(priceless)': False,
#   'contains(accumulate)': False,
#   'contains(brewster)': False,
#   'contains(takin)': False,
#   'contains(seesaw)': False,
#   'contains(trick)': False,
#   'contains(banjotooie)': False,
#   'contains(singin)': False,
#   'contains(tracking)': False,
#   'contains(karlee)': False,
#   'contains(muffin)': False,
#   'contains(milton)': False,
#   'contains(frisbee)': False,
#   'contains(credits)': False,
#   'contains(dissertation)': False,
#   'contains(rains)': False,
#   'contains(highschool)': False,
#   'contains(calm)': False,
#   'contains(ppls)': False,
#   'contains(boatingsongwriting)': False,
#   'contains(unitl)': False,
#   'contains(onelegged)': False,
#   'contains(prelvn)': False,
#   'contains(perham)': False,
#   'contains(que)': False,
#   'contains(twitterlandim)': False,
#   'contains(graveyard)': False,
#   'contains(thy)': False,
#   'contains(divorce)': False,
#   'contains(wes)': False,
#   'contains(emporium)': False,
#   'contains(manalberto)': False,
#   'contains(waas)': False,
#   'contains(raspa)': False,
#   'contains(movie)': False,
#   'contains(suede)': False,
#   'contains(experiment)': False,
#   'contains(colombia)': False,
#   'contains(offers)': False,
#   'contains(hijacked)': False,
#   'contains(ahhso)': False,
#   'contains(bernard)': False,
#   'contains(sickly)': False,
#   'contains(urangan)': False,
#   'contains(weeding)': False,
#   'contains(hottass)': False,
#   'contains(deserves)': False,
#   'contains(pitbull)': False,
#   'contains(butbutbut)': False,
#   'contains(ko)': False,
#   'contains(pussing)': False,
#   'contains(gercekten)': False,
#   'contains(ikr)': False,
#   'contains(charger)': False,
#   'contains(bradie)': False,
#   'contains(forever)': False,
#   'contains(everytime)': False,
#   'contains(jt)': False,
#   'contains(reade)': False,
#   'contains(twitterific)': False,
#   'contains(texas)': False,
#   'contains(youdidnt)': False,
#   'contains(lovefind)': False,
#   'contains(constraints)': False,
#   'contains(ladidadida)': False,
#   'contains(journeys)': False,
#   'contains(philly)': False,
#   'contains(eagerly)': False,
#   'contains(woodlouse)': False,
#   'contains(based)': False,
#   'contains(sudden)': False,
#   'contains(nightor)': False,
#   'contains(none)': False,
#   'contains(vet)': False,
#   'contains(fancy)': False,
#   'contains(chldren)': False,
#   'contains(experiences)': False,
#   'contains(buffython)': False,
#   'contains(remake)': False,
#   'contains(matty)': False,
#   'contains(wavy)': False,
#   'contains(yeahthat)': False,
#   'contains(sken)': False,
#   'contains(migraines)': False,
#   'contains(unloading)': False,
#   'contains(riley)': False,
#   'contains(picor)': False,
#   'contains(prepping)': False,
#   'contains(pala)': False,
#   'contains(services)': False,
#   'contains(elle)': False,
#   'contains(replacement)': False,
#   'contains(station)': False,
#   'contains(berat)': False,
#   'contains(caneuon)': False,
#   'contains(nou)': False,
#   'contains(extrano)': False,
#   'contains(bachelorette)': False,
#   'contains(howcome)': False,
#   'contains(throwing)': False,
#   'contains(miniature)': False,
#   'contains(sinuses)': False,
#   'contains(fm)': False,
#   'contains(whines)': False,
#   'contains(cece)': False,
#   'contains(merrysayy)': False,
#   'contains(crunch)': False,
#   'contains(skyping)': False,
#   'contains(havnt)': False,
#   'contains(loafing)': False,
#   'contains(diduknowthe)': False,
#   'contains(aboout)': False,
#   'contains(depends)': False,
#   'contains(chihuahuas)': False,
#   'contains(navy)': False,
#   'contains(farina)': False,
#   'contains(arpeggio)': False,
#   'contains(actress)': False,
#   'contains(bushes)': False,
#   'contains(updating)': False,
#   'contains(usual)': False,
#   'contains(experiance)': False,
#   'contains(runrers)': False,
#   'contains(enjoy)': False,
#   'contains(haunts)': False,
#   'contains(blasty)': False,
#   'contains(watchin)': False,
#   'contains(monterrey)': False,
#   'contains(lenka)': False,
#   'contains(darkteasing)': False,
#   'contains(stayed)': False,
#   'contains(retarted)': False,
#   'contains(vetcastration)': False,
#   'contains(serani)': False,
#   'contains(startup)': False,
#   'contains(panettiere)': False,
#   'contains(pressed)': False,
#   'contains(intense)': False,
#   'contains(swindon)': False,
#   'contains(constantly)': False,
#   'contains(unc)': False,
#   'contains(chocolates)': False,
#   'contains(sup)': False,
#   'contains(wiiand)': False,
#   'contains(slave)': False,
#   'contains(migraine)': False,
#   'contains(meetings)': False,
#   'contains(owch)': False,
#   'contains(earthquaake)': False,
#   'contains(add)': False,
#   'contains(masks)': False,
#   'contains(shazaam)': False,
#   'contains(barenaked)': False,
#   'contains(boatloads)': False,
#   'contains(ohh)': False,
#   'contains(kane)': False,
#   'contains(hahaahaa)': False,
#   'contains(watchdog)': False,
#   'contains(likee)': False,
#   'contains(actively)': False,
#   'contains(righthasnl)': False,
#   'contains(vegan)': False,
#   'contains(happier)': False,
#   'contains(deckedout)': False,
#   'contains(espload)': False,
#   'contains(bgt)': False,
#   'contains(lights)': False,
#   'contains(difficult)': False,
#   'contains(chewy)': False,
#   'contains(scooby)': False,
#   'contains(stones)': False,
#   'contains(visions)': False,
#   'contains(wa)': False,
#   'contains(heavy)': False,
#   'contains(uh)': False,
#   'contains(customise)': False,
#   'contains(enrollment)': False,
#   'contains(snore)': False,
#   'contains(appears)': False,
#   'contains(posers)': False,
#   'contains(renee)': False,
#   'contains(eviler)': False,
#   'contains(donnie)': False,
#   'contains(naseb)': False,
#   'contains(captors)': False,
#   'contains(carpentry)': False,
#   'contains(turnout)': False,
#   'contains(cartwheels)': False,
#   'contains(nagging)': False,
#   'contains(selfpromo)': False,
#   'contains(shoe)': False,
#   'contains(convo)': False,
#   'contains(hoodrat)': False,
#   'contains(crysoo)': False,
#   'contains(indefinately)': False,
#   'contains(wdnt)': False,
#   'contains(yeeaahh)': False,
#   'contains(infraccion)': False,
#   'contains(payday)': False,
#   'contains(tremble)': False,
#   'contains(recording)': False,
#   'contains(peta)': False,
#   'contains(croissant)': False,
#   'contains(astronomy)': False,
#   'contains(irl)': False,
#   'contains(urgs)': False,
#   'contains(customized)': False,
#   'contains(blond)': False,
#   'contains(preparing)': False,
#   'contains(dirty)': False,
#   'contains(hiya)': False,
#   'contains(childrenbut)': False,
#   'contains(las)': False,
#   'contains(reports)': False,
#   'contains(chapstick)': False,
#   'contains(chatty)': False,
#   'contains(merlins)': False,
#   'contains(spectacular)': False,
#   'contains(weight)': False,
#   'contains(pneu)': False,
#   'contains(greensboro)': False,
#   'contains(wake)': False,
#   'contains(annoy)': False,
#   'contains(kaadikang)': False,
#   'contains(finniest)': False,
#   'contains(voucher)': False,
#   'contains(hayfever)': False,
#   'contains(mommas)': False,
#   'contains(embarrassed)': False,
#   'contains(gta4)': False,
#   'contains(greeaatt)': False,
#   'contains(grri)': False,
#   'contains(apology)': False,
#   'contains(ryan)': False,
#   'contains(chantelle)': False,
#   'contains(nerd)': False,
#   'contains(heartbroken)': False,
#   'contains(pies)': False,
#   'contains(pple)': False,
#   'contains(smiles)': False,
#   'contains(pleeaas)': False,
#   'contains(hopefullyi)': False,
#   'contains(lessons)': False,
#   'contains(lip)': False,
#   'contains(seven)': False,
#   'contains(cholesterol)': False,
#   'contains(izzy)': False,
#   'contains(benz)': False,
#   'contains(slighty)': False,
#   'contains(kid)': False,
#   'contains(ovation)': False,
#   'contains(maisie)': False,
#   'contains(hook)': False,
#   'contains(notoo)': False,
#   'contains(suggestions)': False,
#   'contains(thn)': False,
#   'contains(light)': False,
#   'contains(evil)': False,
#   'contains(extraordinary)': False,
#   'contains(thailand)': False,
#   'contains(overslept)': False,
#   'contains(lighthouse)': False,
#   'contains(gross)': False,
#   'contains(fingerspelling)': False,
#   'contains(commands)': False,
#   'contains(dodgeball)': False,
#   'contains(ivory)': False,
#   'contains(animaniacs)': False,
#   'contains(indigestion)': False,
#   'contains(hundreds)': False,
#   'contains(cheezy)': False,
#   'contains(kelly)': False,
#   'contains(remix)': False,
#   'contains(weep)': False,
#   'contains(strength)': False,
#   'contains(literally)': False,
#   'contains(hangout)': False,
#   'contains(mahers)': False,
#   'contains(whip)': False,
#   'contains(natalie)': False,
#   'contains(ano)': False,
#   'contains(display)': False,
#   'contains(brakefast)': False,
#   'contains(undergrowth)': False,
#   'contains(jake)': False,
#   'contains(savannah)': False,
#   'contains(mixed)': False,
#   'contains(bill)': False,
#   'contains(cuddle)': False,
#   'contains(tonite)': False,
#   'contains(exactly)': False,
#   'contains(anyway)': False,
#   'contains(fixing)': False,
#   'contains(livejournal)': False,
#   'contains(dude)': False,
#   'contains(fass)': False,
#   'contains(gna)': False,
#   'contains(jessy)': False,
#   'contains(pbr)': False,
#   'contains(hangin)': False,
#   'contains(homiefavthe)': False,
#   'contains(commerical)': False,
#   'contains(shul)': False,
#   'contains(kristencant)': False,
#   'contains(lengkap)': False,
#   'contains(secrets)': False,
#   'contains(baker)': False,
#   'contains(wry)': False,
#   'contains(tassie)': False,
#   'contains(strung)': False,
#   'contains(twists)': False,
#   'contains(keens)': False,
#   'contains(pls)': False,
#   'contains(cookand)': False,
#   'contains(startups)': False,
#   'contains(superconducting)': False,
#   'contains(nowt)': False,
#   'contains(union)': False,
#   'contains(flyingstill)': False,
#   'contains(lurve)': False,
#   'contains(cuanto)': False,
#   'contains(slightly)': False,
#   'contains(goz)': False,
#   'contains(attacking)': False,
#   'contains(tomorrowpartycake)': False,
#   'contains(lastt)': False,
#   'contains(whatwill)': False,
#   'contains(alphabetize)': False,
#   'contains(soundtrack)': False,
#   'contains(jumping)': False,
#   'contains(sincerely)': False,
#   'contains(wikipedia)': False,
#   'contains(ticketmaster)': False,
#   'contains(strawberry)': False,
#   'contains(snack)': False,
#   'contains(lcutm)': False,
#   'contains(interview)': False,
#   'contains(original)': False,
#   'contains(chance)': False,
#   'contains(jewel)': False,
#   'contains(foodwant)': False,
#   'contains(bugsnot)': False,
#   'contains(domino)': False,
#   'contains(tasting)': False,
#   'contains(potatohead)': False,
#   'contains(co)': False,
#   'contains(wwatchin)': False,
#   'contains(typhoid)': False,
#   'contains(oncementally)': False,
#   'contains(crn)': False,
#   'contains(base)': False,
#   'contains(gb)': False,
#   'contains(swimmingill)': False,
#   'contains(heartland)': False,
#   'contains(dressed)': False,
#   'contains(varsity)': False,
#   'contains(heartburn)': False,
#   'contains(masses)': False,
#   'contains(alot)': False,
#   'contains(tel)': False,
#   'contains(crapped)': False,
#   'contains(eyebrows)': False,
#   'contains(chk)': False,
#   'contains(meandamn)': False,
#   'contains(impossible)': False,
#   'contains(overwhelmed)': False,
#   'contains(awhh)': False,
#   'contains(crashingbaptisms)': False,
#   'contains(birra)': False,
#   'contains(customs)': False,
#   'contains(tas)': False,
#   'contains(tuna)': False,
#   'contains(communication)': False,
#   'contains(themwhats)': False,
#   'contains(woodworkwoodshopcarpentry)': False,
#   'contains(believers)': False,
#   'contains(everneeds)': False,
#   'contains(grasier)': False,
#   'contains(shool)': False,
#   'contains(makin)': False,
#   'contains(remixed)': False,
#   'contains(hugs)': False,
#   'contains(romancescomedies)': False,
#   'contains(developer)': False,
#   'contains(droped)': False,
#   'contains(manbut)': False,
#   'contains(biggie)': False,
#   'contains(prices)': False,
#   'contains(helium)': False,
#   'contains(simply)': False,
#   'contains(havana)': False,
#   'contains(forcing)': False,
#   'contains(happens)': False,
#   'contains(watchingvit)': False,
#   'contains(eden)': False,
#   'contains(tedxru)': False,
#   'contains(hucked)': False,
#   'contains(cherubs)': False,
#   'contains(sel)': False,
#   'contains(crime)': False,
#   'contains(atls)': False,
#   'contains(scum)': False,
#   'contains(systema)': False,
#   'contains(yuckyy)': False,
#   'contains(deserving)': False,
#   'contains(explode)': False,
#   'contains(rings)': False,
#   'contains(winery)': False,
#   'contains(sps)': False,
#   'contains(images)': False,
#   'contains(cowinkidink)': False,
#   'contains(teenie)': False,
#   'contains(guytake)': False,
#   'contains(lolii)': False,
#   'contains(phonecall)': False,
#   'contains(drilled)': False,
#   'contains(penguiinn)': False,
#   'contains(buhh)': False,
#   'contains(worrying)': False,
#   'contains(snappy)': False,
#   'contains(talkjust)': False,
#   'contains(rocher)': False,
#   'contains(antibiotics)': False,
#   'contains(pg)': False,
#   'contains(vivas)': False,
#   'contains(adsl)': False,
#   'contains(spicy)': False,
#   'contains(lychee)': False,
#   'contains(tisa)': False,
#   'contains(foster)': False,
#   'contains(fathers)': False,
#   'contains(ironchef)': False,
#   'contains(spendin)': False,
#   'contains(coffee)': False,
#   'contains(laptopi)': False,
#   'contains(pursue)': False,
#   'contains(dolphins)': False,
#   'contains(lifes)': False,
#   'contains(ur)': False,
#   'contains(taters)': False,
#   'contains(homeyjus)': False,
#   'contains(incrediblei)': False,
#   'contains(brightening)': False,
#   'contains(action)': False,
#   'contains(dentist)': False,
#   'contains(foxy)': False,
#   'contains(sean)': False,
#   'contains(bestfriend)': False,
#   'contains(option)': False,
#   'contains(rules)': False,
#   'contains(conferences)': False,
#   'contains(feast)': False,
#   'contains(ax)': False,
#   'contains(marked)': False,
#   'contains(nob)': False,
#   'contains(funespecially)': False,
#   'contains(daughters)': False,
#   'contains(elmhurst)': False,
#   'contains(didn)': False,
#   'contains(e3)': False,
#   'contains(ubisoft)': False,
#   'contains(gorg)': False,
#   'contains(regardss)': False,
#   'contains(flops)': False,
#   'contains(stresses)': False,
#   'contains(alumni)': False,
#   'contains(decent)': False,
#   'contains(appreciated)': False,
#   'contains(arty)': False,
#   'contains(amazing)': False,
#   'contains(complain)': False,
#   'contains(paolo)': False,
#   'contains(boots)': False,
#   'contains(poofy)': False,
#   'contains(machinees)': False,
#   'contains(chuffed)': False,
#   'contains(accepting)': False,
#   'contains(dubstep)': False,
#   'contains(heheheehe)': False,
#   'contains(mondays)': False,
#   'contains(fearful)': False,
#   'contains(devo)': False,
#   'contains(ti)': False,
#   'contains(barn)': False,
#   'contains(warmed)': False,
#   'contains(lox)': False,
#   'contains(catalogue)': False,
#   'contains(mbira)': False,
#   'contains(okoff)': False,
#   'contains(wtk)': False,
#   'contains(ir)': False,
#   'contains(hyped)': False,
#   'contains(lonely)': False,
#   'contains(entry)': False,
#   'contains(jlsofficial)': False,
#   'contains(giant)': False,
#   'contains(hellaa)': False,
#   'contains(foolishjust)': False,
#   'contains(n2)': False,
#   'contains(weekand)': False,
#   'contains(feverhow)': False,
#   'contains(l0ve)': False,
#   'contains(threads)': False,
#   'contains(bumps)': False,
#   'contains(conks)': False,
#   'contains(mesh)': False,
#   'contains(launce)': False,
#   'contains(nicotine)': False,
#   'contains(bsb)': False,
#   'contains(wow)': False,
#   'contains(hu)': False,
#   'contains(demis)': False,
#   'contains(axed)': False,
#   'contains(bonfire)': False,
#   'contains(sho)': False,
#   'contains(postrenaissance)': False,
#   'contains(care)': False,
#   'contains(barbque)': False,
#   'contains(bloomsday)': False,
#   'contains(yoyo)': False,
#   'contains(tais)': False,
#   'contains(obviouslyto)': False,
#   'contains(pracy)': False,
#   'contains(blockbuster)': False,
#   'contains(striking)': False,
#   'contains(twist)': False,
#   'contains(bon)': False,
#   'contains(copywill)': False,
#   'contains(astrologyi)': False,
#   'contains(pim)': False,
#   'contains(maytes)': False,
#   'contains(thaanx)': False,
#   'contains(againmanaged)': False,
#   'contains(located)': False,
#   'contains(turkeys)': False,
#   'contains(cuddles)': False,
#   'contains(creamy)': False,
#   'contains(dana)': False,
#   'contains(passion)': False,
#   'contains(newspapers)': False,
#   'contains(amphi)': False,
#   'contains(internests)': False,
#   'contains(backseat)': False,
#   'contains(vt09)': False,
#   'contains(adult)': False,
#   'contains(hhahahaha)': False,
#   'contains(negate)': False,
#   'contains(stalk)': False,
#   'contains(virginiaeating)': False,
#   'contains(gobbs)': False,
#   'contains(saymoving)': False,
#   'contains(excel)': False,
#   'contains(fantasmic)': False,
#   'contains(clark)': False,
#   'contains(punishment)': False,
#   'contains(personally)': False,
#   'contains(huuge)': False,
#   'contains(punk)': False,
#   'contains(stalker)': False,
#   'contains(rand)': False,
#   'contains(blk)': False,
#   'contains(underbelly)': False,
#   'contains(saturate)': False,
#   'contains(evergo)': False,
#   'contains(robert)': False,
#   'contains(gagged)': False,
#   'contains(atv)': False,
#   'contains(whos)': False,
#   'contains(gmornin)': False,
#   'contains(reliable)': False,
#   'contains(ouchness)': False,
#   'contains(ground)': False,
#   'contains(staci)': False,
#   'contains(didnt)': False,
#   'contains(regards)': False,
#   'contains(dictionarycom)': False,
#   'contains(wayid)': False,
#   'contains(eepc)': False,
#   'contains(lolits)': False,
#   'contains(qc)': False,
#   'contains(mc)': False,
#   'contains(gear)': False,
#   'contains(town)': False,
#   'contains(snub)': False,
#   'contains(bingcom)': False,
#   'contains(perfume)': False,
#   'contains(butim)': False,
#   'contains(leopard)': False,
#   'contains(hahano)': False,
#   'contains(teach)': False,
#   'contains(creatures)': False,
#   'contains(mrtweet)': False,
#   'contains(sms)': False,
#   'contains(backend)': False,
#   'contains(wrighty)': False,
#   'contains(resisting)': False,
#   'contains(leverage)': False,
#   'contains(pleased)': False,
#   'contains(placebo)': False,
#   'contains(knead)': False,
#   'contains(sesh)': False,
#   'contains(babyy)': False,
#   'contains(asshole)': False,
#   'contains(bolc)': False,
#   'contains(buhows)': False,
#   'contains(larue)': False,
#   'contains(outside)': False,
#   'contains(seth)': False,
#   'contains(perv)': False,
#   'contains(mms)': False,
#   'contains(pregnancy)': False,
#   'contains(limp)': False,
#   'contains(stomache)': False,
#   'contains(esther)': False,
#   'contains(jaded)': False,
#   'contains(noticesorry)': False,
#   'contains(reduced)': False,
#   'contains(scoop)': False,
#   'contains(lb)': False,
#   'contains(simpsons)': False,
#   'contains(hurts)': False,
#   'contains(voting)': False,
#   'contains(bewski)': False,
#   'contains(guessdo)': False,
#   'contains(versatile)': False,
#   'contains(debating)': False,
#   'contains(nova)': False,
#   'contains(discography)': False,
#   'contains(redwings)': False,
#   'contains(burger)': False,
#   'contains(grade)': False,
#   'contains(xchange)': False,
#   'contains(bulldogs)': False,
#   'contains(rumor)': False,
#   'contains(baseball)': False,
#   'contains(faction)': False,
#   'contains(setback)': False,
#   'contains(invested)': False,
#   'contains(cribjust)': False,
#   'contains(romeo)': False,
#   'contains(cookie)': False,
#   'contains(fondue)': False,
#   'contains(sums)': False,
#   'contains(hp4)': False,
#   'contains(gorgeous)': False,
#   'contains(manage)': False,
#   'contains(namita)': False,
#   'contains(v15)': False,
#   'contains(reeks)': False,
#   'contains(burgers)': False,
#   'contains(july3rd)': False,
#   'contains(venue)': False,
#   'contains(van)': False,
#   'contains(question)': False,
#   'contains(makeover)': False,
#   'contains(hout)': False,
#   'contains(homepuhleeze)': False,
#   'contains(uuggh)': False,
#   'contains(confusing)': False,
#   'contains(usb)': False,
#   'contains(cliff)': False,
#   'contains(recommendations)': False,
#   'contains(gaah)': False,
#   'contains(kcool)': False,
#   'contains(matt)': False,
#   'contains(twitterenjoy)': False,
#   'contains(chilling)': False,
#   'contains(styling)': False,
#   'contains(rnb)': False,
#   'contains(shh)': False,
#   'contains(overdose)': False,
#   'contains(grave)': False,
#   'contains(pre)': False,
#   'contains(winanother)': False,
#   'contains(juz)': False,
#   'contains(stocking)': False,
#   'contains(hunger)': False,
#   'contains(puzzles)': False,
#   'contains(vw)': False,
#   'contains(freezing)': False,
#   'contains(jugak)': False,
#   'contains(jerry)': False,
#   'contains(conan)': False,
#   'contains(bluetooth)': False,
#   'contains(bathnow)': False,
#   'contains(bagging)': False,
#   'contains(breed)': False,
#   'contains(aladdin)': False,
#   'contains(tragedy)': False,
#   'contains(jewiz)': False,
#   'contains(according)': False,
#   'contains(recliner)': False,
#   'contains(nuggets)': False,
#   'contains(success)': False,
#   'contains(edit)': False,
#   'contains(rai)': False,
#   'contains(reunion)': False,
#   'contains(invited)': False,
#   'contains(combat)': False,
#   'contains(meetuptweetupgirlgeekdindin)': False,
#   'contains(alternative)': False,
#   'contains(nomad)': False,
#   'contains(desperation)': False,
#   'contains(fastest)': False,
#   'contains(autopilot)': False,
#   'contains(myboth)': False,
#   'contains(fleamarket)': False,
#   'contains(operi)': False,
#   'contains(shuttle)': False,
#   'contains(source)': False,
#   'contains(adjusted)': False,
#   'contains(hm)': False,
#   'contains(nikolas)': False,
#   'contains(peruto)': False,
#   'contains(optus)': False,
#   'contains(ahha)': False,
#   'contains(nonstop)': False,
#   'contains(cherries)': False,
#   'contains(trek)': False,
#   'contains(shane)': False,
#   'contains(nighthawk)': False,
#   'contains(nowi)': False,
#   'contains(lyssa)': False,
#   'contains(purchases)': False,
#   'contains(item)': False,
#   'contains(duck)': False,
#   'contains(sets)': False,
#   'contains(stanley)': False,
#   'contains(presence)': False,
#   'contains(lisence)': False,
#   'contains(approximately)': False,
#   'contains(headline)': False,
#   'contains(tub)': False,
#   'contains(steak)': False,
#   'contains(savvy)': False,
#   'contains(roberts)': False,
#   'contains(happie)': False,
#   'contains(goanimatecom)': False,
#   'contains(slaggy)': False,
#   'contains(fate)': False,
#   'contains(watchen)': False,
#   'contains(nervous)': False,
#   'contains(humming)': False,
#   'contains(performances)': False,
#   'contains(autobiography)': False,
#   'contains(brasilhi)': False,
#   'contains(commin)': False,
#   'contains(tablets)': False,
#   'contains(unfair)': False,
#   'contains(theory)': False,
#   'contains(nightynight)': False,
#   'contains(gravity)': False,
#   'contains(dough)': False,
#   'contains(ao)': False,
#   'contains(wins)': False,
#   'contains(hatee)': False,
#   'contains(fabric)': False,
#   'contains(electrical)': False,
#   'contains(multimedia)': False,
#   'contains(res)': False,
#   'contains(seriously)': False,
#   'contains(pajamas)': False,
#   'contains(amanda)': False,
#   'contains(mileycyrus)': False,
#   'contains(cims)': False,
#   'contains(believed)': False,
#   'contains(dice)': False,
#   'contains(politically)': False,
#   'contains(lyric)': False,
#   'contains(amazingg)': False,
#   'contains(human)': False,
#   'contains(wireless)': False,
#   'contains(aaw)': False,
#   'contains(inspiration)': False,
#   'contains(zajicek)': False,
#   'contains(touches)': False,
#   'contains(feet)': False,
#   'contains(six)': False,
#   'contains(mass)': False,
#   'contains(fourth)': False,
#   'contains(chalk)': False,
#   'contains(cont)': False,
#   'contains(ec)': False,
#   'contains(ourl)': False,
#   'contains(forsaken)': False,
#   'contains(endand)': False,
#   'contains(trained)': False,
#   'contains(ceiling)': False,
#   'contains(dealy)': False,
#   'contains(els)': False,
#   'contains(season)': False,
#   'contains(flipside)': False,
#   'contains(communards)': False,
#   'contains(lag)': False,
#   'contains(medicines)': False,
#   ...},
#  '"negative"')

# %% [markdown]
# ## Classifier Algorithm : Naive Bayes Classifier
#
# At this point, we have a training set, so all we need to do is instantiate a classifier and classify test tweets. The below code explains how to classify a single tweet using the classifier.
#
# Uses Bayes theorem of probability to predict the class of unknown data set.
#
# P(A|B) = (P(B|A).P(A))/P(B)
#
# Naive Bayes classifier assumes that the presence of a particular feature in a class is unrelated to the presence of any other feature.

# %% [raw]
# #Train the classifier
# NBClassifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [raw]
# #pickle the above file
# import pickle
#
# pickle_out = open("NBC_Save.pickle","wb")
# pickle.dump(NBClassifier, pickle_out)
# pickle_out.close()

# %%
l1 = [12,21,54,2365,323,723,624,624,73]
import pickle

pickle_out = open("list_l1_save.pickle","wb")
pickle.dump(l1, pickle_out)
pickle_out.close()

# %%
l1
# Out:
# [12, 21, 54, 2365, 323, 723, 624, 624, 73]

# %%
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6cf485bc2797> in <module>()
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
pickle_in = open("list_l1_save.pickle","rb")
restored_l1 = pickle.load(pickle_in)

# %%
restored_l1
# Out:
# [12, 21, 54, 2365, 323, 723, 624, 624, 73]

# %%
# Load when required
import pickle
pickle_in = open("NBC_Save.pickle","rb")
NBClassifier = pickle.load(pickle_in)

# %%
test_tweet = "I am so glad to use this service. Extremely satisfied and happy with @gateway hotel"

# %%
processedTestTweet = processTweet(test_tweet)
processedTestTweet
feature_words = extract_features(getFeatureVector(processedTestTweet,stopWords))
feature_words
# Out:
# {'contains(patiently)': False,
#  'contains(rainin)': False,
#  'contains(favourite)': False,
#  'contains(eve)': False,
#  'contains(mushroom)': False,
#  'contains(sales)': False,
#  'contains(wew)': False,
#  'contains(batman)': False,
#  'contains(comming)': False,
#  'contains(twitterin)': False,
#  'contains(yesso)': False,
#  'contains(skype)': False,
#  'contains(im)': False,
#  'contains(arthurs)': False,
#  'contains(stage)': False,
#  'contains(swindon)': False,
#  'contains(soda)': False,
#  'contains(buddy)': False,
#  'contains(missyou)': False,
#  'contains(dave)': False,
#  'contains(soyeepee)': False,
#  'contains(prr)': False,
#  'contains(westside)': False,
#  'contains(ilyy)': False,
#  'contains(carry)': False,
#  'contains(gtg)': False,
#  'contains(veal)': False,
#  'contains(bonfire)': False,
#  'contains(brandon)': False,
#  'contains(cast2009)': False,
#  'contains(reason)': False,
#  'contains(tag)': False,
#  'contains(zealand)': False,
#  'contains(ummyea)': False,
#  'contains(separating)': False,
#  'contains(dough)': False,
#  'contains(gigs)': False,
#  'contains(dicky)': False,
#  'contains(uzvardi)': False,
#  'contains(uniform)': False,
#  'contains(alt)': False,
#  'contains(ful)': False,
#  'contains(unibody)': False,
#  'contains(commenters)': False,
#  'contains(straightenin)': False,
#  'contains(tasteless)': False,
#  'contains(tinsy)': False,
#  'contains(crawfish)': False,
#  'contains(swinging)': False,
#  'contains(settle)': False,
#  'contains(chinatown)': False,
#  'contains(sight)': False,
#  'contains(buggered)': False,
#  'contains(miracle)': False,
#  'contains(via)': False,
#  'contains(goodjust)': False,
#  'contains(fantasy)': False,
#  'contains(chesty)': False,
#  'contains(memorize)': False,
#  'contains(nsx)': False,
#  'contains(blame)': False,
#  'contains(panic)': False,
#  'contains(cliff)': False,
#  'contains(peanut)': False,
#  'contains(likin)': False,
#  'contains(flurries)': False,
#  'contains(mumbo)': False,
#  'contains(beforeafter)': False,
#  'contains(hittin)': False,
#  'contains(vera)': False,
#  'contains(lens)': False,
#  'contains(no1s)': False,
#  'contains(marys)': False,
#  'contains(linning)': False,
#  'contains(toegther)': False,
#  'contains(tomorrowhope)': False,
#  'contains(chalk)': False,
#  'contains(nick)': False,
#  'contains(spit)': False,
#  'contains(racism)': False,
#  'contains(madness)': False,
#  'contains(wireless)': False,
#  'contains(certification)': False,
#  'contains(wwdc)': False,
#  'contains(coughing)': False,
#  'contains(threethe)': False,
#  'contains(joel)': False,
#  'contains(shelter)': False,
#  'contains(screw)': False,
#  'contains(systems)': False,
#  'contains(europesince)': False,
#  'contains(mentn)': False,
#  'contains(bahahahaha)': False,
#  'contains(twirly)': False,
#  'contains(prog)': False,
#  'contains(lakers)': False,
#  'contains(perham)': False,
#  'contains(customs)': False,
#  'contains(amphi)': False,
#  'contains(bogaurding)': False,
#  'contains(drove)': False,
#  'contains(zanders)': False,
#  'contains(steanne)': False,
#  'contains(trooublee)': False,
#  'contains(caption)': False,
#  'contains(baddespite)': False,
#  'contains(nom)': False,
#  'contains(kola)': False,
#  'contains(mornings)': False,
#  'contains(rummer)': False,
#  'contains(prepaid)': False,
#  'contains(refuses)': False,
#  'contains(resetting)': False,
#  'contains(expect)': False,
#  'contains(ipswich)': False,
#  'contains(gamesmake)': False,
#  'contains(eght)': False,
#  'contains(upgrades)': False,
#  'contains(butt)': False,
#  'contains(familywell)': False,
#  'contains(footer)': False,
#  'contains(pool)': False,
#  'contains(democrats)': False,
#  'contains(map)': False,
#  'contains(justice)': False,
#  'contains(dispute)': False,
#  'contains(laptop)': False,
#  'contains(exammeans)': False,
#  'contains(whew)': False,
#  'contains(closed)': False,
#  'contains(bawain)': False,
#  'contains(racist)': False,
#  'contains(croissant)': False,
#  'contains(weeding)': False,
#  'contains(lying)': False,
#  'contains(doll)': False,
#  'contains(elise)': False,
#  'contains(ire)': False,
#  'contains(boys)': False,
#  'contains(doggies)': False,
#  'contains(guitaror)': False,
#  'contains(shantal)': False,
#  'contains(haunting)': False,
#  'contains(canadano)': False,
#  'contains(voila)': False,
#  'contains(press)': False,
#  'contains(fallin)': False,
#  'contains(scd)': False,
#  'contains(iwant)': False,
#  'contains(munites)': False,
#  'contains(funeral)': False,
#  'contains(correction)': False,
#  'contains(soothing)': False,
#  'contains(wealthy)': False,
#  'contains(cuddle)': False,
#  'contains(nutella)': False,
#  'contains(shoulda)': False,
#  'contains(jumbo)': False,
#  'contains(vallejo)': False,
#  'contains(omen)': False,
#  'contains(hotdog)': False,
#  'contains(nga)': False,
#  'contains(whispering)': False,
#  'contains(alcohol)': False,
#  'contains(happiest)': False,
#  'contains(breast)': False,
#  'contains(conferences)': False,
#  'contains(uninterrupted)': False,
#  'contains(shasta)': False,
#  'contains(finale)': False,
#  'contains(warren)': False,
#  'contains(dare)': False,
#  'contains(kickin)': False,
#  'contains(blow)': False,
#  'contains(safari)': False,
#  'contains(speak)': False,
#  'contains(parks)': False,
#  'contains(cyprus)': False,
#  'contains(piled)': False,
#  'contains(payingha)': False,
#  'contains(consumed)': False,
#  'contains(edgefest)': False,
#  'contains(femaleness)': False,
#  'contains(sheepagain)': False,
#  'contains(tri)': False,
#  'contains(msysgit)': False,
#  'contains(minifridge)': False,
#  'contains(performances)': False,
#  'contains(vodka)': False,
#  'contains(bois)': False,
#  'contains(keyring)': False,
#  'contains(bridges)': False,
#  'contains(peoples)': False,
#  'contains(hye)': False,
#  'contains(yaa)': False,
#  'contains(paralyze)': False,
#  'contains(homiefavthe)': False,
#  'contains(musta)': False,
#  'contains(crusade)': False,
#  'contains(band)': False,
#  'contains(rolo)': False,
#  'contains(pleease)': False,
#  'contains(tribunal)': False,
#  'contains(poetic)': False,
#  'contains(stress)': False,
#  'contains(sores)': False,
#  'contains(koko)': False,
#  'contains(attention)': False,
#  'contains(neice)': False,
#  'contains(woah)': False,
#  'contains(returns)': False,
#  'contains(intel)': False,
#  'contains(crusty)': False,
#  'contains(eurgh)': False,
#  'contains(susiewilson)': False,
#  'contains(various)': False,
#  'contains(tattoos)': False,
#  'contains(motorcycle)': False,
#  'contains(deaf)': False,
#  'contains(thatlol)': False,
#  'contains(enjoyable)': False,
#  'contains(godfather)': False,
#  'contains(stupid)': False,
#  'contains(marx)': False,
#  'contains(frozen)': False,
#  'contains(ambush)': False,
#  'contains(arie)': False,
#  'contains(kate)': False,
#  'contains(woods)': False,
#  'contains(carriage)': False,
#  'contains(humorlol)': False,
#  'contains(digital)': False,
#  'contains(origins)': False,
#  'contains(liz)': False,
#  'contains(niid)': False,
#  'contains(cathie)': False,
#  'contains(wheres)': False,
#  'contains(crofts)': False,
#  'contains(tomm)': False,
#  'contains(panicness)': False,
#  'contains(carried)': False,
#  'contains(gi)': False,
#  'contains(woorking)': False,
#  'contains(mgm)': False,
#  'contains(searching)': False,
#  'contains(grades)': False,
#  'contains(vinci)': False,
#  'contains(facility)': False,
#  'contains(smiles)': False,
#  'contains(greet)': False,
#  'contains(lie)': False,
#  'contains(pill)': False,
#  'contains(justine)': False,
#  'contains(youdidnt)': False,
#  'contains(posh)': False,
#  'contains(fitting)': False,
#  'contains(clogged)': False,
#  'contains(crew)': False,
#  'contains(fabius)': False,
#  'contains(lip)': False,
#  'contains(combine)': False,
#  'contains(jungle)': False,
#  'contains(whoavery)': False,
#  'contains(losses)': False,
#  'contains(saddlike)': False,
#  'contains(jalfreezi)': False,
#  'contains(pleasantly)': False,
#  'contains(witness)': False,
#  'contains(child)': False,
#  'contains(owned)': False,
#  'contains(uhh)': False,
#  'contains(mermaid)': False,
#  'contains(sweetheartand)': False,
#  'contains(pointless)': False,
#  'contains(todaywellexcept)': False,
#  'contains(jk)': False,
#  'contains(meesterbette)': False,
#  'contains(highs)': False,
#  'contains(howve)': False,
#  'contains(amylea)': False,
#  'contains(boring)': False,
#  'contains(brew)': False,
#  'contains(badly)': False,
#  'contains(cinemas)': False,
#  'contains(replys)': False,
#  'contains(conrad)': False,
#  'contains(gathering)': False,
#  'contains(wheelchair)': False,
#  'contains(rida)': False,
#  'contains(xox)': False,
#  'contains(tethering)': False,
#  'contains(tele)': False,
#  'contains(realised)': False,
#  'contains(cruises)': False,
#  'contains(tonighthope)': False,
#  'contains(understanding)': False,
#  'contains(bte)': False,
#  'contains(facebooki)': False,
#  'contains(wholee)': False,
#  'contains(sec)': False,
#  'contains(rub)': False,
#  'contains(ditto)': False,
#  'contains(levelsthen)': False,
#  'contains(fifth)': False,
#  'contains(summertime)': False,
#  'contains(glen)': False,
#  'contains(headfones)': False,
#  'contains(m25)': False,
#  'contains(coutys)': False,
#  'contains(twenty20)': False,
#  'contains(cartoon)': False,
#  'contains(scheduled)': False,
#  'contains(journey)': False,
#  'contains(brainstorming)': False,
#  'contains(calm)': False,
#  'contains(pgsql)': False,
#  'contains(dill)': False,
#  'contains(thinkbut)': False,
#  'contains(helpful)': False,
#  'contains(cosplaying)': False,
#  'contains(fans)': False,
#  'contains(edin)': False,
#  'contains(gettn)': False,
#  'contains(univerese)': False,
#  'contains(aawurl)': False,
#  'contains(grandmas)': False,
#  'contains(happiness)': False,
#  'contains(jonashe)': False,
#  'contains(ramps)': False,
#  'contains(habit)': False,
#  'contains(gttin)': False,
#  'contains(cds)': False,
#  'contains(fix)': False,
#  'contains(boarding)': False,
#  'contains(leavethey)': False,
#  'contains(bene)': False,
#  'contains(pics)': False,
#  'contains(attmpt)': False,
#  'contains(coil)': False,
#  'contains(elearning)': False,
#  'contains(rand)': False,
#  'contains(thin)': False,
#  'contains(replaced)': False,
#  'contains(skills)': False,
#  'contains(intro)': False,
#  'contains(skoolbut)': False,
#  'contains(fabric)': False,
#  'contains(dono)': False,
#  'contains(relatives)': False,
#  'contains(tiime)': False,
#  'contains(ultracatchy)': False,
#  'contains(overcast)': False,
#  'contains(jas)': False,
#  'contains(spazz)': False,
#  'contains(undergrowth)': False,
#  'contains(ahve)': False,
#  'contains(nic)': False,
#  'contains(affairs)': False,
#  'contains(unicorn)': False,
#  'contains(cought)': False,
#  'contains(douchebags)': False,
#  'contains(gw)': False,
#  'contains(docked)': False,
#  'contains(westlife)': False,
#  'contains(brakspear)': False,
#  'contains(gorg)': False,
#  'contains(holes)': False,
#  'contains(walauzz)': False,
#  'contains(oxm)': False,
#  'contains(bat)': False,
#  'contains(hiabout)': False,
#  'contains(focus)': False,
#  'contains(chico)': False,
#  'contains(teaches)': False,
#  'contains(whoohoo)': False,
#  'contains(yallim)': False,
#  'contains(soundtrack)': False,
#  'contains(zachy)': False,
#  'contains(twitterdating)': False,
#  'contains(partyin)': False,
#  'contains(debbz)': False,
#  'contains(sachie)': False,
#  'contains(bananas)': False,
#  'contains(kefe)': False,
#  'contains(westwood)': False,
#  'contains(narks)': False,
#  'contains(dmr)': False,
#  'contains(bras)': False,
#  'contains(necessairily)': False,
#  'contains(ysterday)': False,
#  'contains(example)': False,
#  'contains(chalo)': False,
#  'contains(forced)': False,
#  'contains(shoulders)': False,
#  'contains(bulldogs)': False,
#  'contains(unrelated)': False,
#  'contains(draining)': False,
#  'contains(strting)': False,
#  'contains(okgood)': False,
#  'contains(spiders)': False,
#  'contains(caats)': False,
#  'contains(indicator)': False,
#  'contains(safety)': False,
#  'contains(pjs)': False,
#  'contains(remembers)': False,
#  'contains(affirmations)': False,
#  'contains(hunk)': False,
#  'contains(nambu)': False,
#  'contains(stand)': False,
#  'contains(forever21)': False,
#  'contains(weirdest)': False,
#  'contains(mini)': False,
#  'contains(awman)': False,
#  'contains(wellington)': False,
#  'contains(clt)': False,
#  'contains(onesi)': False,
#  'contains(greate)': False,
#  'contains(watz)': False,
#  'contains(halfnow)': False,
#  'contains(tutorial)': False,
#  'contains(born2create2)': False,
#  'contains(regents)': False,
#  'contains(feeli)': False,
#  'contains(fwd)': False,
#  'contains(freckle)': False,
#  'contains(sanka)': False,
#  'contains(tweeten)': False,
#  'contains(spanishhaha)': False,
#  'contains(thanks)': False,
#  'contains(neopolitan)': False,
#  'contains(distracted)': False,
#  'contains(forlorn)': False,
#  'contains(poco)': False,
#  'contains(actuallywell)': False,
#  'contains(tis)': False,
#  'contains(cheaper)': False,
#  'contains(funn)': False,
#  'contains(textt)': False,
#  'contains(tying)': False,
#  'contains(butunfortunately)': False,
#  'contains(flower)': False,
#  'contains(aftershocks)': False,
#  'contains(handy)': False,
#  'contains(netroots)': False,
#  'contains(thnx)': False,
#  'contains(effect)': False,
#  'contains(hallamshire)': False,
#  'contains(defensive)': False,
#  'contains(lcg)': False,
#  'contains(whines)': False,
#  'contains(fred)': False,
#  'contains(tobunobuta)': False,
#  'contains(sorrow)': False,
#  'contains(preferred)': False,
#  'contains(referee)': False,
#  'contains(marines)': False,
#  'contains(attenence)': False,
#  'contains(chronic)': False,
#  'contains(wayne)': False,
#  'contains(freshmen)': False,
#  'contains(frenchies)': False,
#  'contains(washerdryer)': False,
#  'contains(dears)': False,
#  'contains(earplugs)': False,
#  'contains(daytona)': False,
#  'contains(chillies)': False,
#  'contains(roots)': False,
#  'contains(commands)': False,
#  'contains(tehy)': False,
#  'contains(detour)': False,
#  'contains(feminem)': False,
#  'contains(austin)': False,
#  'contains(mp3)': False,
#  'contains(discouraged)': False,
#  'contains(cutting)': False,
#  'contains(insane)': False,
#  'contains(capped)': False,
#  'contains(buzzing)': False,
#  'contains(tea)': False,
#  'contains(sounding)': False,
#  'contains(melissas)': False,
#  'contains(helicopters)': False,
#  'contains(sarah)': False,
#  'contains(zuko)': False,
#  'contains(valdicava)': False,
#  'contains(truman)': False,
#  'contains(eng)': False,
#  'contains(prodigy)': False,
#  'contains(actress)': False,
#  'contains(todaytakers)': False,
#  'contains(mintuelike)': False,
#  'contains(nemo)': False,
#  'contains(politics)': False,
#  'contains(shockadelica)': False,
#  'contains(wine)': False,
#  'contains(chating)': False,
#  'contains(circa)': False,
#  'contains(rack)': False,
#  'contains(kasabihan)': False,
#  'contains(realizes)': False,
#  'contains(tesco)': False,
#  'contains(bodega)': False,
#  'contains(signin)': False,
#  'contains(billiger)': False,
#  'contains(moreover)': False,
#  'contains(pizza)': False,
#  'contains(baking)': False,
#  'contains(memleketime)': False,
#  'contains(musica)': False,
#  'contains(walk)': False,
#  'contains(org)': False,
#  'contains(afgan)': False,
#  'contains(jess)': False,
#  'contains(dolpins)': False,
#  'contains(launce)': False,
#  'contains(ummaybe)': False,
#  'contains(whiskers)': False,
#  'contains(icrack)': False,
#  'contains(lover)': False,
#  'contains(tedxru)': False,
#  'contains(lounger)': False,
#  'contains(daddydaughter)': False,
#  'contains(shingles)': False,
#  'contains(barbque)': False,
#  'contains(sonics)': False,
#  'contains(dsitrub)': False,
#  'contains(yrs)': False,
#  'contains(crapp)': False,
#  'contains(theyd)': False,
#  'contains(potatohead)': False,
#  'contains(drive)': False,
#  'contains(liu)': False,
#  'contains(hahaahaa)': False,
#  'contains(elsei)': False,
#  'contains(nahh)': False,
#  'contains(heads)': False,
#  'contains(hortons)': False,
#  'contains(operi)': False,
#  'contains(columns)': False,
#  'contains(kodak)': False,
#  'contains(tumblring)': False,
#  'contains(pei)': False,
#  'contains(smart)': False,
#  'contains(seei)': False,
#  'contains(theyre)': False,
#  'contains(ooh)': False,
#  'contains(creators)': False,
#  'contains(vrea)': False,
#  'contains(nak)': False,
#  'contains(turtle)': False,
#  'contains(partymore)': False,
#  'contains(real)': False,
#  'contains(omfg)': False,
#  'contains(intestinal)': False,
#  'contains(cycle)': False,
#  'contains(uncharted)': False,
#  'contains(quickcam)': False,
#  'contains(dollar)': False,
#  'contains(heehee)': False,
#  'contains(tumambay)': False,
#  'contains(mendocino)': False,
#  'contains(industries)': False,
#  'contains(beginning)': False,
#  'contains(force)': False,
#  'contains(laurenplease)': False,
#  'contains(flawless)': False,
#  'contains(twat)': False,
#  'contains(seville)': False,
#  'contains(feast)': False,
#  'contains(thingy)': False,
#  'contains(pissing)': False,
#  'contains(recorder)': False,
#  'contains(germ)': False,
#  'contains(capable)': False,
#  'contains(unintentionally)': False,
#  'contains(exposing)': False,
#  'contains(papalini)': False,
#  'contains(alchemy)': False,
#  'contains(kautkas)': False,
#  'contains(borough)': False,
#  'contains(boleh)': False,
#  'contains(watchen)': False,
#  'contains(titled)': False,
#  'contains(mailing)': False,
#  'contains(postpone)': False,
#  'contains(dragging)': False,
#  'contains(spent)': False,
#  'contains(yellen)': False,
#  'contains(wench)': False,
#  'contains(congratz)': False,
#  'contains(lia)': False,
#  'contains(basically)': False,
#  'contains(musical)': False,
#  'contains(naw)': False,
#  'contains(dss)': False,
#  'contains(loudtwitter)': False,
#  'contains(shaela)': False,
#  'contains(channels)': False,
#  'contains(gudmorning)': False,
#  'contains(menuahh)': False,
#  'contains(metroid)': False,
#  'contains(fucckk)': False,
#  'contains(wicked)': False,
#  'contains(brainwashed)': False,
#  'contains(bldy)': False,
#  'contains(trimmer)': False,
#  'contains(magician)': False,
#  'contains(chasis)': False,
#  'contains(kristelle)': False,
#  'contains(pimp)': False,
#  'contains(inout)': False,
#  'contains(report)': False,
#  'contains(breeze)': False,
#  'contains(english)': False,
#  'contains(homies)': False,
#  'contains(housing)': False,
#  'contains(vectors)': False,
#  'contains(nw)': False,
#  'contains(bakers)': False,
#  'contains(fat)': False,
#  'contains(fin)': False,
#  'contains(underground)': False,
#  'contains(ppal)': False,
#  'contains(iam)': False,
#  'contains(sharing)': False,
#  'contains(ghosthunters)': False,
#  'contains(cakes)': False,
#  'contains(hit40uk)': False,
#  'contains(fest)': False,
#  'contains(icey)': False,
#  'contains(anythin)': False,
#  'contains(cum)': False,
#  'contains(tengo)': False,
#  'contains(heated)': False,
#  'contains(recovered)': False,
#  'contains(generalist)': False,
#  'contains(portals)': False,
#  'contains(exists)': False,
#  'contains(diego)': False,
#  'contains(beutiful)': False,
#  'contains(september)': False,
#  'contains(nap)': False,
#  'contains(barenaked)': False,
#  'contains(whateversmymoodhereingmyipodthinking)': False,
#  'contains(wisconsin)': False,
#  'contains(college)': False,
#  'contains(drake)': False,
#  'contains(sunburnt)': False,
#  'contains(headshot)': False,
#  'contains(pasarela)': False,
#  'contains(mitchel)': False,
#  'contains(louboutin)': False,
#  'contains(rogerssad)': False,
#  'contains(photoshopped)': False,
#  'contains(brothershahaha)': False,
#  'contains(yupp)': False,
#  'contains(collegue)': False,
#  'contains(doom)': False,
#  'contains(dandy)': False,
#  'contains(woaah)': False,
#  'contains(applied)': False,
#  'contains(bannana)': False,
#  'contains(marshall)': False,
#  'contains(rds)': False,
#  'contains(darko)': False,
#  'contains(hardest)': False,
#  'contains(feelingi)': False,
#  'contains(citizens)': False,
#  'contains(tomoro)': False,
#  'contains(camden)': False,
#  'contains(fixing)': False,
#  'contains(mani)': False,
#  'contains(security)': False,
#  'contains(okbest)': False,
#  'contains(scorching)': False,
#  'contains(questions)': False,
#  'contains(booki)': False,
#  'contains(totes)': False,
#  'contains(splinter)': False,
#  'contains(freshman)': False,
#  'contains(sweaty)': False,
#  'contains(suckish)': False,
#  'contains(teammate)': False,
#  'contains(wardwork)': False,
#  'contains(brr)': False,
#  'contains(actually)': False,
#  'contains(bemyselfif)': False,
#  'contains(atashinchi)': False,
#  'contains(induction)': False,
#  'contains(cuanto)': False,
#  'contains(round)': False,
#  'contains(touch)': False,
#  'contains(mergreat)': False,
#  'contains(sine)': False,
#  'contains(yikes)': False,
#  'contains(mmh)': False,
#  'contains(monies)': False,
#  'contains(philosophizationing)': False,
#  'contains(dogs)': False,
#  'contains(awesomer)': False,
#  'contains(il)': False,
#  'contains(gear)': False,
#  'contains(halle)': False,
#  'contains(phonogram)': False,
#  'contains(purse)': False,
#  'contains(virginia)': False,
#  'contains(tescos)': False,
#  'contains(corries)': False,
#  'contains(appealing)': False,
#  'contains(areasthis)': False,
#  'contains(tortoisegit)': False,
#  'contains(koolits)': False,
#  'contains(dms)': False,
#  'contains(tentative)': False,
#  'contains(photobucket)': False,
#  'contains(looking)': False,
#  'contains(fts)': False,
#  'contains(diagonally)': False,
#  'contains(schould)': False,
#  'contains(strawberrieshow)': False,
#  'contains(thurr)': False,
#  'contains(thembut)': False,
#  'contains(comein)': False,
#  'contains(dads)': False,
#  'contains(flies)': False,
#  'contains(resched)': False,
#  'contains(christine)': False,
#  'contains(homegood)': False,
#  'contains(goodnight)': False,
#  'contains(hahahahahhaah)': False,
#  'contains(reset)': False,
#  'contains(tmrwso)': False,
#  'contains(jammin)': False,
#  'contains(hupdateeas)': False,
#  'contains(predicted)': False,
#  'contains(fuckin)': False,
#  'contains(rental)': False,
#  'contains(attempting)': False,
#  'contains(foeva)': False,
#  'contains(cantelope)': False,
#  'contains(pg)': False,
#  'contains(vodkaredbull)': False,
#  'contains(sposed)': False,
#  'contains(putput)': False,
#  'contains(saturation)': False,
#  'contains(farhnam)': False,
#  'contains(xong)': False,
#  'contains(fraquinho)': False,
#  'contains(kellys)': False,
#  'contains(tomorrowpartycake)': False,
#  'contains(wo)': False,
#  'contains(okoff)': False,
#  'contains(tweople)': False,
#  'contains(hidden)': False,
#  'contains(joan)': False,
#  'contains(hall)': False,
#  'contains(engine)': False,
#  'contains(mariqueen)': False,
#  'contains(ace)': False,
#  'contains(pointy)': False,
#  'contains(wkend)': False,
#  'contains(bedcos)': False,
#  'contains(oreos)': False,
#  'contains(poem)': False,
#  'contains(loverheri)': False,
#  'contains(schaffen)': False,
#  'contains(lbs)': False,
#  'contains(snappy)': False,
#  'contains(churchh)': False,
#  'contains(spaceys)': False,
#  'contains(dehydration)': False,
#  'contains(hoarse)': False,
#  'contains(definite)': False,
#  'contains(booth)': False,
#  'contains(icky)': False,
#  'contains(rsys)': False,
#  'contains(eyeagain)': False,
#  'contains(craft)': False,
#  'contains(slip)': False,
#  'contains(spider)': False,
#  'contains(mall)': False,
#  'contains(inlaws)': False,
#  'contains(restoring)': False,
#  'contains(stickamcomsowrongitscourt)': False,
#  'contains(turkish)': False,
#  'contains(bobbie)': False,
#  'contains(tiredtaking)': False,
#  'contains(bucklol)': False,
#  'contains(pressure)': False,
#  'contains(boyfrand)': False,
#  'contains(dustin)': False,
#  'contains(orientation)': False,
#  'contains(claim)': False,
#  'contains(carb)': False,
#  'contains(e3)': False,
#  'contains(evil)': False,
#  'contains(swim)': False,
#  'contains(roadkill)': False,
#  'contains(rascall)': False,
#  'contains(bagging)': False,
#  'contains(item)': False,
#  'contains(purtyfull)': False,
#  'contains(hav3)': False,
#  'contains(dinara)': False,
#  'contains(amrutanjal)': False,
#  'contains(asparagus)': False,
#  'contains(disse)': False,
#  'contains(date)': False,
#  'contains(signal)': False,
#  'contains(benefit)': False,
#  'contains(pigeon)': False,
#  'contains(celebrating)': False,
#  'contains(strawberry)': False,
#  'contains(sneak)': False,
#  'contains(timesit)': False,
#  'contains(slices)': False,
#  'contains(somethinglmao)': False,
#  'contains(lower)': False,
#  'contains(daont)': False,
#  'contains(jb)': False,
#  'contains(extremely)': True,
#  'contains(doubtfire)': False,
#  'contains(tomatinos)': False,
#  'contains(xtina)': False,
#  'contains(mechduels)': False,
#  'contains(wtf)': False,
#  'contains(script)': False,
#  'contains(independence)': False,
#  'contains(dexter)': False,
#  'contains(twenty)': False,
#  'contains(manhattan)': False,
#  'contains(unborn)': False,
#  'contains(cupboard)': False,
#  'contains(augusto)': False,
#  'contains(pens)': False,
#  'contains(amazing)': False,
#  'contains(breakhave)': False,
#  'contains(chill)': False,
#  'contains(wrongg)': False,
#  'contains(norwalk)': False,
#  'contains(wel)': False,
#  'contains(meeh)': False,
#  'contains(soccer)': False,
#  'contains(chick)': False,
#  'contains(guvment)': False,
#  'contains(shortlived)': False,
#  'contains(faced)': False,
#  'contains(everlove)': False,
#  'contains(callin)': False,
#  'contains(remind)': False,
#  'contains(beside)': False,
#  'contains(ugly)': False,
#  'contains(rabble)': False,
#  'contains(cheery)': False,
#  'contains(socially)': False,
#  'contains(brightly)': False,
#  'contains(dnw)': False,
#  'contains(bridget)': False,
#  'contains(blankie)': False,
#  'contains(laws)': False,
#  'contains(hoo)': False,
#  'contains(forhead)': False,
#  'contains(sexier)': False,
#  'contains(stayed)': False,
#  'contains(arghi)': False,
#  'contains(def)': False,
#  'contains(handed)': False,
#  'contains(despite)': False,
#  'contains(tires)': False,
#  'contains(ncl)': False,
#  'contains(bridal)': False,
#  'contains(machinees)': False,
#  'contains(squash)': False,
#  'contains(sandwhich)': False,
#  'contains(obnoxiously)': False,
#  'contains(woop)': False,
#  'contains(househappy)': False,
#  'contains(ultimate)': False,
#  'contains(yaye)': False,
#  'contains(sleepingagain)': False,
#  'contains(funnest)': False,
#  'contains(chuckie)': False,
#  'contains(gbear)': False,
#  'contains(fuss)': False,
#  'contains(lizzie)': False,
#  'contains(placebarbri)': False,
#  'contains(bball)': False,
#  'contains(cathy)': False,
#  'contains(pensacolaim)': False,
#  'contains(nicks)': False,
#  'contains(clubbing)': False,
#  'contains(requests)': False,
#  'contains(babysittin)': False,
#  'contains(confusion)': False,
#  'contains(repetitive)': False,
#  'contains(twitterers)': False,
#  'contains(john)': False,
#  'contains(purchase)': False,
#  'contains(whoopass)': False,
#  'contains(bhutan)': False,
#  'contains(cardetailed)': False,
#  'contains(accent)': False,
#  'contains(baked)': False,
#  'contains(travesty)': False,
#  'contains(welshs)': False,
#  'contains(elysha)': False,
#  'contains(padfoot)': False,
#  'contains(hmmthis)': False,
#  'contains(bachelorette)': False,
#  'contains(rafa)': False,
#  'contains(mayo)': False,
#  'contains(iraheta)': False,
#  'contains(longshot)': False,
#  'contains(suffery)': False,
#  'contains(singalongs)': False,
#  'contains(lleyton)': False,
#  'contains(chemo)': False,
#  'contains(voted)': False,
#  'contains(virus)': False,
#  'contains(miam)': False,
#  'contains(palms)': False,
#  'contains(jaja)': False,
#  'contains(gagawin)': False,
#  'contains(frustratinghave)': False,
#  'contains(seenalmost)': False,
#  'contains(ducks)': False,
#  'contains(heheeh)': False,
#  'contains(val)': False,
#  'contains(manky)': False,
#  'contains(congrats)': False,
#  'contains(former)': False,
#  'contains(screwed)': False,
#  'contains(liburan)': False,
#  'contains(definately)': False,
#  'contains(glassez)': False,
#  'contains(ideas)': False,
#  'contains(von)': False,
#  'contains(tofollows)': False,
#  'contains(showerwhy)': False,
#  'contains(material)': False,
#  'contains(partyinit)': False,
#  'contains(pakistan)': False,
#  'contains(seriously)': False,
#  'contains(toilet)': False,
#  'contains(frantic)': False,
#  'contains(overflowing)': False,
#  'contains(crapped)': False,
#  'contains(ludivines)': False,
#  'contains(oasis)': False,
#  'contains(pregnant)': False,
#  'contains(onbut)': False,
#  'contains(michael)': False,
#  'contains(chemist)': False,
#  'contains(volleyball)': False,
#  'contains(nance)': False,
#  'contains(tabs)': False,
#  'contains(crunch)': False,
#  'contains(warcraft)': False,
#  'contains(treasury)': False,
#  'contains(rush)': False,
#  'contains(beefin)': False,
#  'contains(respectful)': False,
#  'contains(rockets)': False,
#  'contains(khaleejesque)': False,
#  'contains(slayer)': False,
#  'contains(weed)': False,
#  'contains(fising)': False,
#  'contains(demand)': False,
#  'contains(haayits)': False,
#  'contains(jetskiing)': False,
#  'contains(intraday)': False,
#  'contains(l4d2)': False,
#  'contains(wuss)': False,
#  'contains(contact)': False,
#  'contains(lighting)': False,
#  'contains(lemsip)': False,
#  'contains(slaggy)': False,
#  'contains(stalled)': False,
#  'contains(kat)': False,
#  'contains(ny)': False,
#  'contains(vella)': False,
#  'contains(awards)': False,
#  'contains(command)': False,
#  'contains(adorable)': False,
#  'contains(insulted)': False,
#  'contains(otherside)': False,
#  'contains(peter)': False,
#  'contains(babysit)': False,
#  'contains(kenny)': False,
#  'contains(mucho)': False,
#  'contains(aborted)': False,
#  'contains(alla)': False,
#  'contains(crn)': False,
#  'contains(menu)': False,
#  'contains(bac)': False,
#  'contains(rai)': False,
#  'contains(reed)': False,
#  'contains(squire)': False,
#  'contains(pa)': False,
#  'contains(bubbless)': False,
#  ...}

# %%
NBClassifier.classify(feature_words) # testing
# Out:
# '"positive"'

# %%
testTweet = "pathetic service by @jetairways. Seat belts aren't proper!"
processedTestTweet = processTweet(testTweet)
print(NBClassifier.classify(extract_features(getFeatureVector(processedTestTweet,stopWords))))
# Out:
# "negative"

# %%
print(NBClassifier.show_most_informative_features(10))

# %%
testTweet = 'Pathetic staff, worse service. Never flying with #AirIndianaJones'
processedTestTweet = processTweet(testTweet)
print(NBClassifier.classify(extract_features(getFeatureVector(processedTestTweet,stopWords))))
# Out:
# "negative"

# %%
test = "I bought onepluse6t product on 1st Nov and today my phone cameras are not working . Please consider my experience with OnePlus before you buying this product."
processedTestTweet = processTweet(test)
print(NBClassifier.classify(extract_features(getFeatureVector(processedTestTweet,stopWords))))
# Out:
# "negative"

# %%
test = "Wonderful product, so happy and satified despite all the bad and negative reviews. They are all lies and fake"
processedTestTweet = processTweet(test)
print(NBClassifier.classify(extract_features(getFeatureVector(processedTestTweet,stopWords))))
# Out:
# "positive"

# %% [markdown]
# ---
# #### Getting our test data from Twitter by connecting to it via API

# %% [raw]
# # config.json
#
# {
#     "consumer_key": "YOUR CONSUMER KEY",
#     "consumer_secret": "YOUR CONSUMER SECRET",
#     "access_token": "YOUR ACCESS TOKEN",
#     "access_token_secret": "YOUR ACCESS TOKEN SECRET"
# }

# %% [raw]
# https://developer.twitter.com/en/docs/api-reference-index
#
# # How to connect?
# https://auth0.com/docs/connections/social/twitter

# %% [raw]
# tweepy

# %% [raw]
# pip install twython
# # tweepy

# %%
from twython import Twython  
import json

# Load credentials from json file
with open("TwitterAPI/config.json", "r") as file:  
    creds = json.load(file)

# Instantiate an object
python_tweets = Twython(creds['consumer_key'], creds['consumer_secret'],creds['access_token'], creds['access_token_secret'])

# Create our query
query = {'q': 'VijayDiwas',  
        'result_type': 'popular',
        'count': 10000,
        'lang': 'en',
        }

# %%
import pandas as pd

# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'favorite_count': []}  
for status in python_tweets.search(**query)['statuses']:  
    dict_['user'].append(status['user']['screen_name'])
    dict_['date'].append(status['created_at'])
    dict_['text'].append(status['text'])
    dict_['favorite_count'].append(status['favorite_count'])

# Structure data in a pandas DataFrame for easier manipulation
df = pd.DataFrame(dict_)  
df.head(5)
# Out:
# Empty DataFrame
# Columns: [user, date, text, favorite_count]
# Index: []

# %%
# Or read a timeline
twitter =Twython()

user_timeline = python_tweets.get_user_timeline(screen_name="iamsrk")
# And print the tweets for that user.
pm_modi = []
for tweet in user_timeline:
    pm_modi.append(tweet['text'])

# %%
sentiment = []
for test in pm_modi:
    processedTestTweet = processTweet(test)
    feature_words = extract_features(getFeatureVector(processedTestTweet,stopWords))
    sentiment.append(NBClassifier.classify(feature_words))

# %%
pd.concat([pd.Series(pm_modi),pd.Series(sentiment)],axis=1,keys=["tweet","sentiment"])
# Out:
#                                                 tweet   sentiment
# 0   No no yaar. The fun was all mine. You were so ...  "positive"
# 1   Wonderful play by @RealShubmanGill &amp; @Russ...  "negative"
# 2   And he was so jovial. Somehow in the midst of ...  "positive"
# 3   He loved me so much. Encouraged me. And today ...  "negative"
# 4   Sir film aapki hai…acting aapki hai…Hit aapki ...  "positive"
# 5   Sir hum toh wait kar rahein hain ki aap party ...  "positive"
# 6   Thought while waiting to go back home to Mumba...  "negative"
# 7   Much fun in Chennai today. Well played @Chenna...  "positive"
# 8   How sweet is this from @purevnv  now I have be...  "positive"
# 9   Thanks baby. Got this. Now please motivate me ...  "positive"
# 10  So well done my @KKRiders @lynny50 give him th...  "positive"
# 11  Well played boys @KKRiders @lynny50 @NitishRan...  "positive"
# 12  And you guys in the Dugout who said game/set/&...  "negative"
# 13  Thank u for the honour @universityoflaw &amp; ...  "positive"
# 14  What a lovely evening @Arsenal congratulations...  "positive"
# 15  The end of one story is the beginning of anoth...  "positive"
# 16  All of u please put ur hands in prayer...and s...  "positive"
# 17  Aaj ki Shaam Eden Gardens ke Naam...All at KKR...  "positive"
# 18  Next time you please come to the grounds Didi....  "positive"
# 19  “Being with you is like being on Stage. There’...  "negative"

# %%
from textblob import TextBlob

# %%
TextBlob("She is a beautiful woman").detect_language()
# Out:
# 'en'

# %%
TextBlob("वह एक सुन्दर महिला है").detect_language()
# Out:
# 'hi'

# %%
TextBlob("kuch bhi bolo").detect_language()
# Out:
# 'en'

# %%
TextBlob.translator.translate("वह एक सुन्दर महिला है")
# Out:
# 'She is a beautiful lady'

# %%
TextBlob.translator.translate("Er ist weider da")
# Out:
# 'He is here'

# %%
TextBlob.translator.translate("kuch bhi bolo")
# Out:
# ---------------------------------------------------------------------------
# NotTranslated                             Traceback (most recent call last)
# <ipython-input-39-fc9a705587ad> in <module>()
# ----> 1 TextBlob.translator.translate("kuch bhi bolo")
#
# ~\anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      59             except IndexError:
#      60                 pass
# ---> 61         self._validate_translation(source, result)
#      62         return result
#      63
#
# ~\anaconda3\lib\site-packages\textblob\translate.py in _validate_translation(self, source, result)
#      83             result = result.encode('utf-8')
#      84         if result.strip() == source.strip():
# ---> 85             raise NotTranslated('Translation API returned the input string unchanged.')
#      86
#      87     def _request(self, url, host=None, type_=None, data=None):
#
# NotTranslated: Translation API returned the input string unchanged.

# %%
# Further Tasks

# 1. Properly clean the training data (SampleTrainingData.csv)
# 2. Ignore non English text when training
#     Hint : nltk can identify the language
             Also, it can transalate the words
# 3. Control the twitter feed (for validation dataset):
#     a. No of tweets
#     b. Time line for the tweets
#     c. get tweets for a topic only from a geographical area (topic : OnePlus, then get tweets from India)
# the nltk has certain functions to ID
#     d. Identify the language used in the tweets
#     e. Remove/translate non-english tweets

# %%
# 1. Email classification LDA
#    document classification github

# 2. Text scrubbing

# 3. Log file extraction automation
