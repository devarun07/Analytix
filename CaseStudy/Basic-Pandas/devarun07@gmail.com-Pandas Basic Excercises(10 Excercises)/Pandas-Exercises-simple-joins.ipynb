# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the  datasets [cars1.csv](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars1.csv) and [cars2.csv](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars2.csv) from the folder

# %% [markdown]
#    ### Step 3. Assign each to a to a variable called cars1 and cars2

# %%
cars1 = pd.read_csv('C:\Analytix\Assignments\Dataset\cars1.csv')
cars2 = pd.read_csv('C:\Analytix\Assignments\Dataset\cars2.csv')

# %% [markdown]
# ### Step 4. It seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1 = cars1.dropna(axis=1)

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
print("The number of observations:")
print("Cars1: {}, Cars2: {}".format(cars1.shape[0],cars2.shape[0]))
# Out:
# The number of observations:
# Cars1: 198, Cars2: 200

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars = pd.concat([cars1,cars2], axis=0)
cars.reset_index(drop=True,inplace=True)
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### Step 7. There is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
owners = np.random.randint(15000,73000,398)
owners
# Out:
# array([49344, 52137, 21334, 45798, 41772, 61245, 26040, 25121, 68480,
#        49246, 43497, 26100, 29651, 51873, 23200, 70462, 38957, 35068,
#        18014, 54700, 21464, 68427, 39913, 71458, 26261, 16665, 23931,
#        40104, 63500, 17491, 67456, 71665, 56065, 66520, 30485, 57704,
#        25044, 18146, 47505, 59452, 35001, 37921, 39065, 36401, 25345,
#        31624, 16191, 36225, 44418, 69267, 51477, 45271, 39530, 67199,
#        67044, 72088, 26664, 33400, 65293, 65706, 15352, 34302, 57439,
#        17152, 52923, 67178, 45401, 46420, 60713, 68599, 62108, 51028,
#        61217, 24864, 38247, 71358, 20973, 20631, 50531, 21427, 65603,
#        57708, 27362, 26974, 45618, 63156, 31237, 48140, 22558, 42335,
#        45915, 44813, 32066, 67081, 68322, 20297, 62495, 51153, 72761,
#        69984, 48224, 21873, 62606, 48643, 16597, 39136, 69784, 63348,
#        52152, 63019, 28866, 46476, 65566, 16667, 37803, 60504, 44520,
# ...

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars['owners'] = owners
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...
